# %%
import numpy as np
import pandas as pd
import patsy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
train = pd.read_csv('./train.csv')

# %%
y = train['SalePrice']
X = train.drop(['SalePrice'], axis = "columns")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1025, 80) (1025,)
# (1026, 80) (1026,)

# %%
null_count = X_train.isnull().sum().to_frame('nulls')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 1620 to 1839
# Data columns (total 80 columns):
# Id                 1025 non-null int64
# PID                1025 non-null int64
# MS SubClass        1025 non-null int64
# MS Zoning          1025 non-null object
# Lot Frontage       866 non-null float64
# Lot Area           1025 non-null int64
# Street             1025 non-null object
# Alley              73 non-null object
# Lot Shape          1025 non-null object
# Land Contour       1025 non-null object
# Utilities          1025 non-null object
# Lot Config         1025 non-null object
# Land Slope         1025 non-null object
# Neighborhood       1025 non-null object
# Condition 1        1025 non-null object
# Condition 2        1025 non-null object
# Bldg Type          1025 non-null object
# House Style        1025 non-null object
# Overall Qual       1025 non-null int64
# Overall Cond       1025 non-null int64
# Year Built         1025 non-null int64
# Year Remod/Add     1025 non-null int64
# Roof Style         1025 non-null object
# Roof Matl          1025 non-null object
# Exterior 1st       1025 non-null object
# Exterior 2nd       1025 non-null object
# Mas Vnr Type       1016 non-null object
# Mas Vnr Area       1016 non-null float64
# Exter Qual         1025 non-null object
# Exter Cond         1025 non-null object
# Foundation         1025 non-null object
# Bsmt Qual          997 non-null object
# Bsmt Cond          997 non-null object
# Bsmt Exposure      995 non-null object
# BsmtFin Type 1     997 non-null object
# BsmtFin SF 1       1024 non-null float64
# BsmtFin Type 2     996 non-null object
# BsmtFin SF 2       1024 non-null float64
# Bsmt Unf SF        1024 non-null float64
# Total Bsmt SF      1024 non-null float64
# Heating            1025 non-null object
# Heating QC         1025 non-null object
# Central Air        1025 non-null object
# Electrical         1025 non-null object
# 1st Flr SF         1025 non-null int64
# 2nd Flr SF         1025 non-null int64
# Low Qual Fin SF    1025 non-null int64
# Gr Liv Area        1025 non-null int64
# Bsmt Full Bath     1024 non-null float64
# Bsmt Half Bath     1024 non-null float64
# Full Bath          1025 non-null int64
# Half Bath          1025 non-null int64
# Bedroom AbvGr      1025 non-null int64
# Kitchen AbvGr      1025 non-null int64
# Kitchen Qual       1025 non-null object
# TotRms AbvGrd      1025 non-null int64
# Functional         1025 non-null object
# Fireplaces         1025 non-null int64
# Fireplace Qu       532 non-null object
# Garage Type        968 non-null object
# Garage Yr Blt      967 non-null float64
# Garage Finish      967 non-null object
# Garage Cars        1024 non-null float64
# Garage Area        1024 non-null float64
# Garage Qual        967 non-null object
# Garage Cond        967 non-null object
# Paved Drive        1025 non-null object
# Wood Deck SF       1025 non-null int64
# Open Porch SF      1025 non-null int64
# Enclosed Porch     1025 non-null int64
# 3Ssn Porch         1025 non-null int64
# Screen Porch       1025 non-null int64
# Pool Area          1025 non-null int64
# Pool QC            5 non-null object
# Fence              200 non-null object
# Misc Feature       22 non-null object
# Misc Val           1025 non-null int64
# Mo Sold            1025 non-null int64
# Yr Sold            1025 non-null int64
# Sale Type          1025 non-null object
# dtypes: float64(11), int64(27), object(42)
# memory usage: 648.6+ KB

# %%
mask = null_count['nulls'] != 0
null_list = null_count[mask]
null_list
# Out:
#                 nulls
# Lot Frontage      159
# Alley             952
# Mas Vnr Type        9
# Mas Vnr Area        9
# Bsmt Qual          28
# Bsmt Cond          28
# Bsmt Exposure      30
# BsmtFin Type 1     28
# BsmtFin SF 1        1
# BsmtFin Type 2     29
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      1
# Bsmt Half Bath      1
# Fireplace Qu      493
# Garage Type        57
# Garage Yr Blt      58
# Garage Finish      58
# Garage Cars         1
# Garage Area         1
# Garage Qual        58
# Garage Cond        58
# Pool QC          1020
# Fence             825
# Misc Feature     1003

# %%
for i in range(80): 
    if [X_train.iloc[: ,i].dtypes!=object] == True:
        mean = X_train.iloc[: ,i].mean()
        X_train.iloc[: ,i].fillna(mean, inplace=True)
    else:
        pass

# %%
str_cols = X_train.columns[X_train.dtypes==object]
#X_train[str_cols] = X_train[str_cols].fillna('None')
#X_train.fillna(0,inplace=True)

# %%
str_cols
# Out:
# Index(['MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
#        'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
#        'Sale Type'],
#       dtype='object')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 1620 to 1839
# Data columns (total 80 columns):
# Id                 1025 non-null int64
# PID                1025 non-null int64
# MS SubClass        1025 non-null int64
# MS Zoning          1025 non-null object
# Lot Frontage       866 non-null float64
# Lot Area           1025 non-null int64
# Street             1025 non-null object
# Alley              73 non-null object
# Lot Shape          1025 non-null object
# Land Contour       1025 non-null object
# Utilities          1025 non-null object
# Lot Config         1025 non-null object
# Land Slope         1025 non-null object
# Neighborhood       1025 non-null object
# Condition 1        1025 non-null object
# Condition 2        1025 non-null object
# Bldg Type          1025 non-null object
# House Style        1025 non-null object
# Overall Qual       1025 non-null int64
# Overall Cond       1025 non-null int64
# Year Built         1025 non-null int64
# Year Remod/Add     1025 non-null int64
# Roof Style         1025 non-null object
# Roof Matl          1025 non-null object
# Exterior 1st       1025 non-null object
# Exterior 2nd       1025 non-null object
# Mas Vnr Type       1016 non-null object
# Mas Vnr Area       1016 non-null float64
# Exter Qual         1025 non-null object
# Exter Cond         1025 non-null object
# Foundation         1025 non-null object
# Bsmt Qual          997 non-null object
# Bsmt Cond          997 non-null object
# Bsmt Exposure      995 non-null object
# BsmtFin Type 1     997 non-null object
# BsmtFin SF 1       1024 non-null float64
# BsmtFin Type 2     996 non-null object
# BsmtFin SF 2       1024 non-null float64
# Bsmt Unf SF        1024 non-null float64
# Total Bsmt SF      1024 non-null float64
# Heating            1025 non-null object
# Heating QC         1025 non-null object
# Central Air        1025 non-null object
# Electrical         1025 non-null object
# 1st Flr SF         1025 non-null int64
# 2nd Flr SF         1025 non-null int64
# Low Qual Fin SF    1025 non-null int64
# Gr Liv Area        1025 non-null int64
# Bsmt Full Bath     1024 non-null float64
# Bsmt Half Bath     1024 non-null float64
# Full Bath          1025 non-null int64
# Half Bath          1025 non-null int64
# Bedroom AbvGr      1025 non-null int64
# Kitchen AbvGr      1025 non-null int64
# Kitchen Qual       1025 non-null object
# TotRms AbvGrd      1025 non-null int64
# Functional         1025 non-null object
# Fireplaces         1025 non-null int64
# Fireplace Qu       532 non-null object
# Garage Type        968 non-null object
# Garage Yr Blt      967 non-null float64
# Garage Finish      967 non-null object
# Garage Cars        1024 non-null float64
# Garage Area        1024 non-null float64
# Garage Qual        967 non-null object
# Garage Cond        967 non-null object
# Paved Drive        1025 non-null object
# Wood Deck SF       1025 non-null int64
# Open Porch SF      1025 non-null int64
# Enclosed Porch     1025 non-null int64
# 3Ssn Porch         1025 non-null int64
# Screen Porch       1025 non-null int64
# Pool Area          1025 non-null int64
# Pool QC            5 non-null object
# Fence              200 non-null object
# Misc Feature       22 non-null object
# Misc Val           1025 non-null int64
# Mo Sold            1025 non-null int64
# Yr Sold            1025 non-null int64
# Sale Type          1025 non-null object
# dtypes: float64(11), int64(27), object(42)
# memory usage: 648.6+ KB

# %%
X_train.head()
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1620   815  906226140           90        RL          64.0      7007   Pave
# 1485   283  908225320           50        RL          52.0      8741   Pave
# 840   1924  535177020           20        RL          70.0      9100   Pave
# 475   2900  916475100           20        RL          85.0     14331   Pave
# 281   1075  528186130          120        RL          89.0      8232   Pave
#
#      Alley Lot Shape Land Contour    ...     3Ssn Porch Screen Porch  \
# 1620   NaN       Reg          Bnk    ...              0            0
# 1485   NaN       Reg          Lvl    ...              0            0
# 840    NaN       Reg          Lvl    ...              0            0
# 475    NaN       Reg          Lvl    ...              0            0
# 281    NaN       IR1          Lvl    ...              0            0
#
#      Pool Area Pool QC  Fence Misc Feature Misc Val Mo Sold  Yr Sold  \
# 1620         0     NaN    NaN          NaN        0       6     2009
# 1485         0     NaN  MnPrv          NaN        0       4     2010
# 840          0     NaN    NaN          NaN        0       6     2007
# 475          0     NaN    NaN          NaN        0       5     2006
# 281          0     NaN    NaN          NaN        0       6     2008
#
#       Sale Type
# 1620        WD
# 1485        WD
# 840         WD
# 475         WD
# 281         New
#
# [5 rows x 80 columns]

# %%
str_cols = X_train.columns[X_train.dtypes==object]
X_train[str_cols] = X_train[str_cols].fillna('AANone')
X_train.fillna(0,inplace=True)
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
X_train.head()
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1620   815  906226140           90        RL          64.0      7007   Pave
# 1485   283  908225320           50        RL          52.0      8741   Pave
# 840   1924  535177020           20        RL          70.0      9100   Pave
# 475   2900  916475100           20        RL          85.0     14331   Pave
# 281   1075  528186130          120        RL          89.0      8232   Pave
#
#        Alley Lot Shape Land Contour    ...     3Ssn Porch Screen Porch  \
# 1620  AANone       Reg          Bnk    ...              0            0
# 1485  AANone       Reg          Lvl    ...              0            0
# 840   AANone       Reg          Lvl    ...              0            0
# 475   AANone       Reg          Lvl    ...              0            0
# 281   AANone       IR1          Lvl    ...              0            0
#
#      Pool Area Pool QC   Fence Misc Feature Misc Val Mo Sold  Yr Sold  \
# 1620         0  AANone  AANone       AANone        0       6     2009
# 1485         0  AANone   MnPrv       AANone        0       4     2010
# 840          0  AANone  AANone       AANone        0       6     2007
# 475          0  AANone  AANone       AANone        0       5     2006
# 281          0  AANone  AANone       AANone        0       6     2008
#
#       Sale Type
# 1620        WD
# 1485        WD
# 840         WD
# 475         WD
# 281         New
#
# [5 rows x 80 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 1620 to 1839
# Data columns (total 80 columns):
# Id                 1025 non-null int64
# PID                1025 non-null int64
# MS SubClass        1025 non-null int64
# MS Zoning          1025 non-null object
# Lot Frontage       1025 non-null float64
# Lot Area           1025 non-null int64
# Street             1025 non-null object
# Alley              1025 non-null object
# Lot Shape          1025 non-null object
# Land Contour       1025 non-null object
# Utilities          1025 non-null object
# Lot Config         1025 non-null object
# Land Slope         1025 non-null object
# Neighborhood       1025 non-null object
# Condition 1        1025 non-null object
# Condition 2        1025 non-null object
# Bldg Type          1025 non-null object
# House Style        1025 non-null object
# Overall Qual       1025 non-null int64
# Overall Cond       1025 non-null int64
# Year Built         1025 non-null int64
# Year Remod/Add     1025 non-null int64
# Roof Style         1025 non-null object
# Roof Matl          1025 non-null object
# Exterior 1st       1025 non-null object
# Exterior 2nd       1025 non-null object
# Mas Vnr Type       1025 non-null object
# Mas Vnr Area       1025 non-null float64
# Exter Qual         1025 non-null object
# Exter Cond         1025 non-null object
# Foundation         1025 non-null object
# Bsmt Qual          1025 non-null object
# Bsmt Cond          1025 non-null object
# Bsmt Exposure      1025 non-null object
# BsmtFin Type 1     1025 non-null object
# BsmtFin SF 1       1025 non-null float64
# BsmtFin Type 2     1025 non-null object
# BsmtFin SF 2       1025 non-null float64
# Bsmt Unf SF        1025 non-null float64
# Total Bsmt SF      1025 non-null float64
# Heating            1025 non-null object
# Heating QC         1025 non-null object
# Central Air        1025 non-null object
# Electrical         1025 non-null object
# 1st Flr SF         1025 non-null int64
# 2nd Flr SF         1025 non-null int64
# Low Qual Fin SF    1025 non-null int64
# Gr Liv Area        1025 non-null int64
# Bsmt Full Bath     1025 non-null float64
# Bsmt Half Bath     1025 non-null float64
# Full Bath          1025 non-null int64
# Half Bath          1025 non-null int64
# Bedroom AbvGr      1025 non-null int64
# Kitchen AbvGr      1025 non-null int64
# Kitchen Qual       1025 non-null object
# TotRms AbvGrd      1025 non-null int64
# Functional         1025 non-null object
# Fireplaces         1025 non-null int64
# Fireplace Qu       1025 non-null object
# Garage Type        1025 non-null object
# Garage Yr Blt      1025 non-null float64
# Garage Finish      1025 non-null object
# Garage Cars        1025 non-null float64
# Garage Area        1025 non-null float64
# Garage Qual        1025 non-null object
# Garage Cond        1025 non-null object
# Paved Drive        1025 non-null object
# Wood Deck SF       1025 non-null int64
# Open Porch SF      1025 non-null int64
# Enclosed Porch     1025 non-null int64
# 3Ssn Porch         1025 non-null int64
# Screen Porch       1025 non-null int64
# Pool Area          1025 non-null int64
# Pool QC            1025 non-null object
# Fence              1025 non-null object
# Misc Feature       1025 non-null object
# Misc Val           1025 non-null int64
# Mo Sold            1025 non-null int64
# Yr Sold            1025 non-null int64
# Sale Type          1025 non-null object
# dtypes: float64(11), int64(27), object(42)
# memory usage: 648.6+ KB

# %%
for col in ['Low Qual Fin SF', 'Gr Liv Area', 'Lot Area', '1st Flr SF', '2nd Flr SF', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val']:
    X_train[col] = X_train[col].astype('float64')
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 1620 to 1839
# Data columns (total 80 columns):
# Id                 1025 non-null int64
# PID                1025 non-null int64
# MS SubClass        1025 non-null int64
# MS Zoning          1025 non-null object
# Lot Frontage       1025 non-null float64
# Lot Area           1025 non-null float64
# Street             1025 non-null object
# Alley              1025 non-null object
# Lot Shape          1025 non-null object
# Land Contour       1025 non-null object
# Utilities          1025 non-null object
# Lot Config         1025 non-null object
# Land Slope         1025 non-null object
# Neighborhood       1025 non-null object
# Condition 1        1025 non-null object
# Condition 2        1025 non-null object
# Bldg Type          1025 non-null object
# House Style        1025 non-null object
# Overall Qual       1025 non-null int64
# Overall Cond       1025 non-null int64
# Year Built         1025 non-null int64
# Year Remod/Add     1025 non-null int64
# Roof Style         1025 non-null object
# Roof Matl          1025 non-null object
# Exterior 1st       1025 non-null object
# Exterior 2nd       1025 non-null object
# Mas Vnr Type       1025 non-null object
# Mas Vnr Area       1025 non-null float64
# Exter Qual         1025 non-null object
# Exter Cond         1025 non-null object
# Foundation         1025 non-null object
# Bsmt Qual          1025 non-null object
# Bsmt Cond          1025 non-null object
# Bsmt Exposure      1025 non-null object
# BsmtFin Type 1     1025 non-null object
# BsmtFin SF 1       1025 non-null float64
# BsmtFin Type 2     1025 non-null object
# BsmtFin SF 2       1025 non-null float64
# Bsmt Unf SF        1025 non-null float64
# Total Bsmt SF      1025 non-null float64
# Heating            1025 non-null object
# Heating QC         1025 non-null object
# Central Air        1025 non-null object
# Electrical         1025 non-null object
# 1st Flr SF         1025 non-null float64
# 2nd Flr SF         1025 non-null float64
# Low Qual Fin SF    1025 non-null float64
# Gr Liv Area        1025 non-null float64
# Bsmt Full Bath     1025 non-null float64
# Bsmt Half Bath     1025 non-null float64
# Full Bath          1025 non-null int64
# Half Bath          1025 non-null int64
# Bedroom AbvGr      1025 non-null int64
# Kitchen AbvGr      1025 non-null int64
# Kitchen Qual       1025 non-null object
# TotRms AbvGrd      1025 non-null int64
# Functional         1025 non-null object
# Fireplaces         1025 non-null int64
# Fireplace Qu       1025 non-null object
# Garage Type        1025 non-null object
# Garage Yr Blt      1025 non-null float64
# Garage Finish      1025 non-null object
# Garage Cars        1025 non-null float64
# Garage Area        1025 non-null float64
# Garage Qual        1025 non-null object
# Garage Cond        1025 non-null object
# Paved Drive        1025 non-null object
# Wood Deck SF       1025 non-null float64
# Open Porch SF      1025 non-null float64
# Enclosed Porch     1025 non-null float64
# 3Ssn Porch         1025 non-null float64
# Screen Porch       1025 non-null float64
# Pool Area          1025 non-null float64
# Pool QC            1025 non-null object
# Fence              1025 non-null object
# Misc Feature       1025 non-null object
# Misc Val           1025 non-null float64
# Mo Sold            1025 non-null int64
# Yr Sold            1025 non-null int64
# Sale Type          1025 non-null object
# dtypes: float64(23), int64(15), object(42)
# memory usage: 648.6+ KB

# %%
int_cols = X_train.columns[X_train.dtypes=='int64']

# %%
int_cols
# Out:
# Index(['MS SubClass', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces', 'Mo Sold', 'Yr Sold'],
#       dtype='object')

# %%
X_train[int_cols] = X_train[int_cols].astype('object')

# %%
len(X_train.columns)
# Out:
# 78

# %% [markdown]
# **Cleaning Done**

# %% [markdown]
# **Cleaning Function**

# %%
def clean_me(df):
    #Replaces Null values outside of object columns 
    for i in range(len(df.columns)): 
        if [df.iloc[: ,i].dtypes!=object] == True:
            mean = df.iloc[: ,i].mean()
            df.iloc[: ,i].fillna(mean, inplace=True)
        else:
            pass
        #Replaces other null values with AANone
    str_cols = df.columns[df.dtypes==object]
    df[str_cols] = df[str_cols].fillna('AANone')
    df.fillna(0,inplace=True)
        #Change selected columns from Int to float
    for col in ['Low Qual Fin SF', 'Gr Liv Area', 'Lot Area', '1st Flr SF', '2nd Flr SF',
                'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val']:
                df[col] = df[col].astype('float64')
        #Makes remaining int colomns objects 
    int_cols = df.columns[df.dtypes=='int64']
    df[int_cols] = df[int_cols].astype('object')
    df = df.drop(['Id', 'PID'], axis=1)
    return df

# %%
X_train.head()
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1579  2742  905452140           50        RL          75.0      9525   Pave
# 1251  1316  902306130           70        RM          60.0      9600   Pave
# 1857  1434  907135260           20        RL          57.0      9245   Pave
# 798    312  914476520           20        RL         129.0      9196   Pave
# 561    956  916176030           20        RL           NaN     14375   Pave
#
#      Alley Lot Shape Land Contour    ...     3Ssn Porch Screen Porch  \
# 1579   NaN       Reg          Lvl    ...              0            0
# 1251   NaN       Reg          Lvl    ...              0            0
# 1857   NaN       IR2          Lvl    ...              0            0
# 798    NaN       IR1          Lvl    ...              0            0
# 561    NaN       IR1          Lvl    ...              0          233
#
#      Pool Area Pool QC Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 1579         0     NaN   NaN          NaN        0      10     2006        WD
# 1251         0     NaN   NaN          NaN        0      10     2008        WD
# 1857         0     NaN   NaN          NaN        0       2     2008        WD
# 798          0     NaN   NaN          NaN        0       4     2010        WD
# 561          0     NaN   NaN          NaN        0       1     2009        COD
#
# [5 rows x 80 columns]

# %%
clean_me(X_train).head()
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      MS SubClass MS Zoning  Lot Frontage  Lot Area Street   Alley Lot Shape  \
# 1579          50        RL          75.0    9525.0   Pave  AANone       Reg
# 1251          70        RM          60.0    9600.0   Pave  AANone       Reg
# 1857          20        RL          57.0    9245.0   Pave  AANone       IR2
# 798           20        RL         129.0    9196.0   Pave  AANone       IR1
# 561           20        RL           0.0   14375.0   Pave  AANone       IR1
#
#      Land Contour Utilities Lot Config    ...    3Ssn Porch Screen Porch  \
# 1579          Lvl    AllPub     Inside    ...           0.0          0.0
# 1251          Lvl    AllPub     Inside    ...           0.0          0.0
# 1857          Lvl    AllPub     Inside    ...           0.0          0.0
# 798           Lvl    AllPub     Inside    ...           0.0          0.0
# 561           Lvl    NoSeWa    CulDSac    ...           0.0        233.0
#
#      Pool Area Pool QC   Fence Misc Feature Misc Val Mo Sold Yr Sold Sale Type
# 1579       0.0  AANone  AANone       AANone      0.0      10    2006       WD
# 1251       0.0  AANone  AANone       AANone      0.0      10    2008       WD
# 1857       0.0  AANone  AANone       AANone      0.0       2    2008       WD
# 798        0.0  AANone  AANone       AANone      0.0       4    2010       WD
# 561        0.0  AANone  AANone       AANone      0.0       1    2009       COD
#
# [5 rows x 78 columns]

# %%
X_train.info()

# %%
clean_me(X_test).head()
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      MS SubClass MS Zoning  Lot Frontage  Lot Area Street   Alley Lot Shape  \
# 720           20        RL          80.0    9547.0   Pave  AANone       Reg
# 997           20        RL          65.0    8450.0   Pave  AANone       Reg
# 1581          60        RL          82.0    9430.0   Pave  AANone       Reg
# 1712          70        RM          50.0    9060.0   Pave  AANone       Reg
# 849           20        RL           0.0   10456.0   Pave  AANone       IR1
#
#      Land Contour Utilities Lot Config    ...    3Ssn Porch Screen Porch  \
# 720           Lvl    AllPub     Inside    ...           0.0          0.0
# 997           Lvl    AllPub     Inside    ...           0.0          0.0
# 1581          Lvl    AllPub     Inside    ...           0.0        180.0
# 1712          Lvl    AllPub     Inside    ...           0.0          0.0
# 849           Lvl    AllPub     Inside    ...           0.0          0.0
#
#      Pool Area Pool QC   Fence Misc Feature Misc Val Mo Sold Yr Sold Sale Type
# 720        0.0  AANone  AANone       AANone      0.0       7    2007       WD
# 997        0.0  AANone   MnPrv       AANone      0.0      11    2006       COD
# 1581       0.0  AANone  AANone       AANone      0.0       7    2009       WD
# 1712       0.0  AANone   MnPrv       AANone      0.0       3    2007       WD
# 849        0.0  AANone  AANone       AANone      0.0       5    2010       WD
#
# [5 rows x 78 columns]

# %% [markdown]
# **Linear Regression Numbers**

# %%
test = pd.read_csv('./test.csv')

# %%
test_id = test['Id']

# %%
clean_me(test)
# Out:
#     MS SubClass MS Zoning  Lot Frontage  Lot Area Street   Alley Lot Shape  \
# 0           190        RM          69.0    9142.0   Pave    Grvl       Reg
# 1            90        RL           0.0    9662.0   Pave  AANone       IR1
# 2            60        RL          58.0   17104.0   Pave  AANone       IR1
# 3            30        RM          60.0    8520.0   Pave  AANone       Reg
# 4            20        RL           0.0    9500.0   Pave  AANone       IR1
# 5           160        RM          21.0    1890.0   Pave  AANone       Reg
# 6            20        RM          52.0    8516.0   Pave  AANone       Reg
# 7            20        RL           0.0    9286.0   Pave  AANone       IR1
# 8           160        FV          39.0    3515.0   Pave    Pave       Reg
# 9            20        RL          75.0   10125.0   Pave  AANone       Reg
# 10          120        RL          50.0    7175.0   Pave  AANone       Reg
# 11           30        RM          60.0    7200.0   Pave  AANone       Reg
# 12           20        RL          75.0   11310.0   Pave  AANone       Reg
# 13           90        RL           0.0    7976.0   Pave  AANone       Reg
# 14           70        RL          69.0   11737.0   Pave  AANone       IR1
# 15           20        RL          60.0    9060.0   Pave  AANone       Reg
# 16          190        RM          60.0   10800.0   Pave    Grvl       Reg
# 17           20        RL          68.0    9571.0   Pave  AANone       Reg
# 18           20        RL          80.0   10800.0   Pave  AANone       Reg
# 19           70        RM         121.0   17671.0   Pave    Grvl       Reg
# 20           20        RL           0.0    8246.0   Pave  AANone       IR1
# 21           20        RL           0.0    8499.0   Pave  AANone       IR1
# 22          120        RL          50.0    8012.0   Pave  AANone       Reg
# 23           80        RL           0.0   21453.0   Pave  AANone       IR1
# 24           20        RL          80.0    9605.0   Pave  AANone       Reg
# 25           20        RL          60.0    7180.0   Pave  AANone       IR1
# 26           50        RL           0.0   12513.0   Pave  AANone       IR1
# 27           70        RM          50.0    9000.0   Pave    Grvl       Reg
# 28           85        RL          80.0    8800.0   Pave  AANone       Reg
# 29           50        RL          51.0    3500.0   Pave  AANone       Reg
# ..          ...       ...           ...       ...    ...     ...       ...
# 849         160        RM          24.0    1733.0   Pave  AANone       Reg
# 850          80        RL          42.0   10385.0   Pave  AANone       IR1
# 851         120        RM          32.0    4500.0   Pave  AANone       Reg
# 852          20        RL           0.0    9790.0   Pave  AANone       Reg
# 853          20        RL          60.0    7332.0   Pave  AANone       Reg
# 854          90        RL           0.0    7032.0   Pave  AANone       IR1
# 855          50        RL          66.0   21780.0   Pave  AANone       Reg
# 856          50        RM          60.0    5790.0   Pave  AANone       Reg
# 857         120        RL          61.0    7380.0   Pave  AANone       IR1
# 858         180        RM          21.0    1526.0   Pave  AANone       Reg
# 859          60        RL          72.0   11317.0   Pave  AANone       Reg
# 860          20        RL           0.0    8780.0   Pave  AANone       IR1
# 861          20        RL          90.0   12378.0   Pave  AANone       IR1
# 862         120        RH          34.0    4058.0   Pave  AANone       Reg
# 863         160        RM          24.0    2368.0   Pave  AANone       Reg
# 864          20        RL          85.0    9350.0   Pave  AANone       Reg
# 865          90        RL          64.0    7040.0   Pave  AANone       Reg
# 866          60        RL          70.0    8749.0   Pave  AANone       Reg
# 867          20        RL           0.0    7777.0   Pave  AANone       IR1
# 868         160        RL           0.0    5062.0   Pave  AANone       IR1
# 869          90        RL          70.0    7700.0   Pave  AANone       Reg
# 870          20        RL           0.0   36500.0   Pave  AANone       IR1
# 871          20        RL         182.0   14572.0   Pave  AANone       IR3
# 872          20        RL          80.0   11844.0   Pave  AANone       IR1
# 873          20        RL          70.0    8810.0   Pave  AANone       Reg
# 874          60        RL          80.0    8000.0   Pave  AANone       Reg
# 875          60        RL          90.0   14670.0   Pave  AANone       Reg
# 876          20        RL          55.0    8250.0   Pave  AANone       Reg
# 877          20        RL          60.0    9000.0   Pave  AANone       Reg
# 878          20        RL          70.0    8400.0   Pave  AANone       Reg
#
#     Land Contour Utilities Lot Config    ...    3Ssn Porch Screen Porch  \
# 0            Lvl    AllPub     Inside    ...           0.0          0.0
# 1            Lvl    AllPub     Inside    ...           0.0          0.0
# 2            Lvl    AllPub     Inside    ...           0.0          0.0
# 3            Lvl    AllPub     Inside    ...           0.0          0.0
# 4            Lvl    AllPub     Inside    ...           0.0        185.0
# 5            Lvl    AllPub     Inside    ...           0.0          0.0
# 6            Lvl    AllPub     Inside    ...           0.0          0.0
# 7            Lvl    AllPub    CulDSac    ...           0.0          0.0
# 8            Lvl    AllPub     Inside    ...           0.0          0.0
# 9            Lvl    AllPub     Inside    ...           0.0          0.0
# 10           Lvl    AllPub     Inside    ...           0.0          0.0
# 11           Lvl    AllPub     Corner    ...           0.0          0.0
# 12           Lvl    AllPub     Inside    ...           0.0          0.0
# 13           Lvl    AllPub     Inside    ...           0.0          0.0
# 14           Bnk    AllPub     Inside    ...           0.0          0.0
# 15           Lvl    AllPub     Inside    ...         180.0          0.0
# 16           Lvl    AllPub     Inside    ...           0.0          0.0
# 17           Lvl    AllPub     Inside    ...           0.0          0.0
# 18           Lvl    AllPub     Inside    ...           0.0        144.0
# 19           Lvl    AllPub     Corner    ...           0.0          0.0
# 20           Lvl    AllPub     Inside    ...           0.0          0.0
# 21           Lvl    AllPub     Corner    ...           0.0          0.0
# 22           Lvl    AllPub     Inside    ...           0.0          0.0
# 23           Low    AllPub    CulDSac    ...         130.0          0.0
# 24           Lvl    AllPub     Corner    ...           0.0          0.0
# 25           Lvl    AllPub     Inside    ...           0.0          0.0
# 26           Lvl    AllPub        FR2    ...           0.0          0.0
# 27           Lvl    AllPub     Corner    ...           0.0          0.0
# 28           Lvl    AllPub     Inside    ...           0.0          0.0
# 29           Lvl    AllPub     Inside    ...           0.0          0.0
# ..           ...       ...        ...    ...           ...          ...
# 849          Lvl    AllPub     Inside    ...           0.0          0.0
# 850          Lvl    AllPub    CulDSac    ...           0.0          0.0
# 851          Lvl    AllPub        FR2    ...           0.0          0.0
# 852          Lvl    AllPub     Inside    ...           0.0        197.0
# 853          Lvl    AllPub     Inside    ...           0.0          0.0
# 854          Lvl    AllPub     Corner    ...           0.0          0.0
# 855          Lvl    AllPub     Inside    ...           0.0        144.0
# 856          Lvl    AllPub     Corner    ...           0.0          0.0
# 857          Lvl    AllPub     Corner    ...           0.0          0.0
# 858          Lvl    AllPub     Inside    ...           0.0          0.0
# 859          Lvl    AllPub     Inside    ...           0.0          0.0
# 860          Lvl    AllPub     Corner    ...           0.0          0.0
# 861          Lvl    AllPub     Inside    ...           0.0          0.0
# 862          Lvl    AllPub     Inside    ...           0.0          0.0
# 863          Lvl    AllPub     Inside    ...           0.0          0.0
# 864          Lvl    AllPub     Inside    ...           0.0        121.0
# 865          Lvl    AllPub     Inside    ...           0.0          0.0
# 866          Lvl    AllPub     Inside    ...           0.0          0.0
# 867          Lvl    AllPub     Inside    ...           0.0          0.0
# 868          Lvl    AllPub    CulDSac    ...           0.0          0.0
# 869          Lvl    AllPub     Inside    ...           0.0          0.0
# 870          Low    AllPub     Inside    ...           0.0          0.0
# 871          Lvl    AllPub     Corner    ...           0.0          0.0
# 872          Lvl    AllPub     Inside    ...           0.0          0.0
# 873          Lvl    AllPub     Inside    ...           0.0          0.0
# 874          Lvl    AllPub     Inside    ...           0.0          0.0
# 875          Lvl    AllPub     Inside    ...           0.0          0.0
# 876          Lvl    AllPub     Inside    ...           0.0          0.0
# 877          Lvl    AllPub        FR2    ...           0.0          0.0
# 878          Lvl    AllPub     Corner    ...           0.0          0.0
#
#     Pool Area Pool QC   Fence Misc Feature Misc Val Mo Sold Yr Sold Sale Type
# 0         0.0  AANone  AANone       AANone      0.0       4    2006       WD
# 1         0.0  AANone  AANone       AANone      0.0       8    2006       WD
# 2         0.0  AANone  AANone       AANone      0.0       9    2006       New
# 3         0.0  AANone  AANone       AANone      0.0       7    2007       WD
# 4         0.0  AANone  AANone       AANone      0.0       7    2009       WD
# 5         0.0  AANone  AANone       AANone      0.0       6    2010       WD
# 6         0.0  AANone  AANone       AANone      0.0       5    2008       WD
# 7         0.0  AANone  AANone       AANone      0.0      10    2009       WD
# 8         0.0  AANone  AANone       AANone      0.0       1    2010       WD
# 9         0.0  AANone   MnPrv       AANone      0.0       2    2008       WD
# 10        0.0  AANone  AANone       AANone      0.0       6    2006       WD
# 11        0.0  AANone  AANone       AANone      0.0       7    2008       WD
# 12        0.0  AANone  AANone       AANone      0.0       6    2006       WD
# 13        0.0  AANone  AANone       AANone      0.0      10    2009       WD
# 14        0.0  AANone   GdPrv       AANone      0.0       5    2006       WD
# 15        0.0  AANone   MnPrv       AANone      0.0       6    2007       WD
# 16        0.0  AANone  AANone       AANone      0.0       5    2008       Con
# 17        0.0  AANone   GdPrv       AANone      0.0       2    2009       WD
# 18        0.0  AANone  AANone       AANone      0.0       8    2006       WD
# 19        0.0  AANone  AANone       AANone      0.0      11    2009       WD
# 20        0.0  AANone   MnPrv       AANone      0.0       5    2010       WD
# 21        0.0  AANone  AANone       AANone      0.0       6    2009       WD
# 22        0.0  AANone  AANone       AANone      0.0       7    2008       WD
# 23        0.0  AANone  AANone       AANone      0.0      10    2006       WD
# 24        0.0  AANone  AANone       AANone      0.0       4    2009       WD
# 25        0.0  AANone  AANone       AANone      0.0       5    2008       WD
# 26        0.0  AANone  AANone       AANone      0.0       6    2009       WD
# 27        0.0  AANone   MnPrv       AANone      0.0       6    2006       WD
# 28        0.0  AANone   MnPrv       AANone      0.0       5    2010       WD
# 29        0.0  AANone   MnPrv         Shed   2000.0       7    2007       WD
# ..        ...     ...     ...          ...      ...     ...     ...       ...
# 849       0.0  AANone   GdPrv       AANone      0.0       5    2009       WD
# 850       0.0  AANone  AANone       AANone      0.0       4    2006       WD
# 851       0.0  AANone  AANone       AANone      0.0       6    2009       WD
# 852       0.0  AANone  AANone       AANone      0.0       9    2009       WD
# 853       0.0  AANone  AANone       AANone      0.0      10    2006       WD
# 854       0.0  AANone  AANone       AANone      0.0      12    2006       WD
# 855       0.0  AANone  AANone       AANone      0.0       7    2008       WD
# 856       0.0  AANone  AANone       AANone      0.0       5    2010       WD
# 857       0.0  AANone  AANone       AANone      0.0       7    2009       WD
# 858       0.0  AANone  AANone       AANone      0.0       5    2009       WD
# 859       0.0  AANone  AANone       AANone      0.0       9    2007       WD
# 860       0.0  AANone   MnPrv       AANone      0.0       3    2009       WD
# 861       0.0  AANone  AANone       AANone      0.0      11    2006       WD
# 862       0.0  AANone  AANone       AANone      0.0       6    2007       WD
# 863       0.0  AANone  AANone       AANone      0.0       5    2009       WD
# 864       0.0  AANone   MnPrv       AANone      0.0       2    2009       WD
# 865       0.0  AANone  AANone       AANone      0.0       6    2009       WD
# 866       0.0  AANone  AANone       AANone      0.0      11    2009       WD
# 867       0.0  AANone  AANone       AANone      0.0      11    2007       WD
# 868       0.0  AANone  AANone       AANone      0.0       9    2007       WD
# 869       0.0  AANone  AANone         Shed    600.0       2    2010       WD
# 870       0.0  AANone  AANone       AANone      0.0       6    2006       WD
# 871       0.0  AANone  AANone       AANone      0.0      11    2007       WD
# 872       0.0  AANone  AANone       AANone      0.0       7    2009       New
# 873       0.0  AANone  AANone       AANone      0.0       3    2006       WD
# 874       0.0  AANone  AANone       AANone      0.0      11    2007       WD
# 875       0.0  AANone   MnPrv       AANone      0.0       8    2008       WD
# 876       0.0  AANone  AANone       AANone      0.0       8    2008       WD
# 877       0.0  AANone    GdWo       AANone      0.0       5    2007       WD
# 878       0.0  AANone    GdWo       AANone      0.0       3    2007       WD
#
# [879 rows x 78 columns]

# %%
float_cols = X_train.columns[X_train.dtypes=='float64']
num_X_train = X_train[float_cols]

# %%
float_cols = X_test.columns[X_test.dtypes=='float64']
num_X_test = X_test[float_cols]

# %%
float_cols = test.columns[test.dtypes=='float64']
num_test = test[float_cols]

# %%
slr = LinearRegression()
slr.fit(num_X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(slr.score(num_X_test, y_test))
# Out:
# 0.6453783148657568

# %%
model =lr.fit(num_X_train, y_train)
y_hat = model.predict(num_test)

# %%
y_hat
# Out:
# array([171364.2180142 , 235724.37803808, 162939.84714622, 115388.36355483,
#        210879.13884148,  87797.85285988, 105438.58272157, 133331.7264873 ,
#        175910.7603706 , 181308.27051106, 160656.90339758, 135310.45119475,
#        171496.85248588, 327327.73457504, 152558.1598886 , 106584.9149097 ,
#        171424.67561288, 124672.20716271, 245769.62679878, 194581.23832728,
#        134452.13951968, 158148.43731508, 215133.86250518, 160585.40761393,
#        171219.16924362,  98959.36416841, 141470.81174676, 121002.93139551,
#        163598.65994532,  44473.91397125, 104905.05948729, 102090.97793872,
#        280415.23523349, 172202.96906256, 215747.96598764, 147592.63032012,
#        153303.68209683,  75147.79620219,  83947.82554632, 191602.45707499,
#        147489.62353372, 176917.54963707, 173768.37732472, 167529.17335845,
#        232532.5543174 ,  90703.84208578, 209079.18051281, 123716.97560018,
#        113412.21551904, 119391.92001135, 105976.97007817, 199591.06686341,
#        244185.11821119, 114181.94731448, 119053.23434259, 154376.79279689,
#        175780.09257203, 157933.93857475, 165455.22242101, 241560.65901161,
#        352513.0699299 , 165883.7685642 , 161257.99049568, 168408.30835816,
#        174488.85340844, 334047.21686586,  80708.32812212, 206055.3930103 ,
#         53859.57900873, 133055.85996753, 101173.08468945, 327305.95663444,
#        205567.48297075, 133598.34980458, 129415.45707652, 235216.71841082,
#        262535.9881199 , 183400.65655919, 337720.54315967,  87775.85823745,
#         98688.81056028, 126894.95871968, 189623.58310184, 261202.91375283,
#        117168.73876095, 275897.76706252, 194983.65285893, 183696.53915223,
#        277759.16369087, 190739.50445703, 315043.55955504, 204966.90429615,
#        185620.20093049, 147408.06264426, 216133.78834573, 254342.10177595,
#        243692.34811456, 139602.18560036, 101061.45874006, 128735.51984245,
#        119536.45694847, 246103.34658977, 108918.31530228, 114657.05523342,
#        145284.31873202, 133478.5281277 , 136734.39971624, 159696.08998501,
#        317633.01370271, 168218.68090997, 220806.90613629, 205116.77560657,
#        182173.61528302, 275547.53002586,  91557.42413218, 128011.92613413,
#        151457.67139658, 199601.84170059, 106899.17741458, 353314.39589046,
#        190827.53722395, 164902.6154853 , 208052.55334076, 372853.88089433,
#        132060.53813648, 232519.93845605, 200981.30641044, 143033.38760798,
#        172383.98806395, 269360.19732369, 181510.80454964, 150089.11862598,
#        126234.97932317, 307901.35960524, 121070.84838661, 112061.00603264,
#        133317.13548283, 247875.91040231, 174540.97426949, 215975.13130941,
#        144643.52059444, 155735.2127658 , 226897.93646523, 294759.20796609,
#        220667.79032885, 111708.62072226, 200197.38047493, 202665.05192767,
#        177229.86016639, 118772.39872392, 144245.17807186, 187941.73063793,
#        130073.40779112, 197392.53220478,  73596.3026852 , 182043.89146417,
#         83039.38631395, 305430.99656846, 111090.44951041, 171766.38209316,
#        210304.34928371, 202889.18733596, 176084.97214811, 193497.21917616,
#        232840.65905559, 241578.59365567, 253271.87609358, 257382.95918349,
#        317977.28596493, 202828.04890177, 222163.04936079, 253211.22435818,
#        130844.74067229, 127081.85191197, 123149.69360196])

# %%
num_trial = pd.DataFrame(y_hat, index = test_id)
num_trial.columns = ['SalePrice']
num_trial.head()
# Out:
#           SalePrice
# Id
# 2658  171364.218014
# 2718  235724.378038
# 2414  162939.847146
# 1989  115388.363555
# 625   210879.138841

# %%
num_trial.to_csv("./num_trial.csv")

# %%
coefs = pd.DataFrame([model.coef_], columns=num_X_train.columns)
coefs.T
# Out:
#                             0
# Lot Frontage       108.427736
# Lot Area             0.035611
# Mas Vnr Area        59.893763
# BsmtFin SF 1        21.756085
# BsmtFin SF 2        10.590919
# Bsmt Unf SF          3.027448
# Total Bsmt SF       35.374453
# 1st Flr SF          41.417540
# 2nd Flr SF          36.547534
# Low Qual Fin SF    -49.232246
# Gr Liv Area         28.732828
# Bsmt Full Bath    4815.524719
# Bsmt Half Bath   -2245.413881
# Garage Yr Blt       -8.022783
# Garage Cars      16129.084077
# Garage Area         43.043057
# Wood Deck SF        27.730196
# Open Porch SF       74.467643
# Enclosed Porch     -52.585937
# 3Ssn Porch          53.398463
# Screen Porch        43.940923
# Pool Area         -161.547056
# Misc Val            -3.068828

# %% [markdown]
# **Linear Regression Numbers 2nd attampt**

# %%
cor_df = num_X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-d8e266b59993> in <module>()
# ----> 1 cor_df = num_X_train
#
# NameError: name 'num_X_train' is not defined

# %%
cor_df['sales'] = y_train
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
cor_num = cor_df.corr()[['sales']]

# %%
cor_num
# Out:
#                     sales
# Lot Frontage     0.179200
# Lot Area         0.250532
# Mas Vnr Area     0.535928
# BsmtFin SF 1     0.416168
# BsmtFin SF 2     0.025242
# Bsmt Unf SF      0.186030
# Total Bsmt SF    0.662023
# 1st Flr SF       0.651799
# 2nd Flr SF       0.275068
# Low Qual Fin SF -0.054607
# Gr Liv Area      0.723401
# Bsmt Full Bath   0.273744
# Bsmt Half Bath  -0.071439
# Garage Yr Blt    0.268427
# Garage Cars      0.648702
# Garage Area      0.654627
# Wood Deck SF     0.328955
# Open Porch SF    0.346585
# Enclosed Porch  -0.115549
# 3Ssn Porch       0.078852
# Screen Porch     0.109257
# Pool Area        0.000899
# Misc Val        -0.033154
# sales            1.000000

# %%
mask = abs(cor_num['sales']) > .5 
new_list = cor_num[mask]
new_list
# Out:
#                   sales
# Mas Vnr Area   0.535928
# Total Bsmt SF  0.662023
# 1st Flr SF     0.651799
# Gr Liv Area    0.723401
# Garage Cars    0.648702
# Garage Area    0.654627
# sales          1.000000

# %%
num_X_train_2 = num_X_train[['Mas Vnr Area', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Garage Cars', 'Garage Area']]

# %%
num_X_test_2 = num_X_test[['Mas Vnr Area', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Garage Cars', 'Garage Area']]

# %%
num_test_2 = num_test[['Mas Vnr Area', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Garage Cars', 'Garage Area']]

# %%
slr.fit(num_X_train_2, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(slr.score(num_X_test_2, y_test))
# Out:
# 0.6166057608771992

# %%
model =lr.fit(num_X_train_2, y_train)
y_hat = model.predict(num_test_2)

# %%
num_trial_2 = pd.DataFrame(y_hat, index = test_id)
num_trial_2.columns = ['SalePrice']
num_trial_2.head()
# Out:
#           SalePrice
# Id
# 2658  188290.083192
# 2718  265923.010941
# 2414  150810.389689
# 1989  137557.887548
# 625   210518.029107

# %%
num_trial_2.to_csv("./num_trial_2.csv")

# %% [markdown]
# **Polynomial Variables from second Numbers**

# %%
poly = PolynomialFeatures(include_bias = False)
X_poly = poly.fit_transform(num_X_train_2)

# %%
poly = PolynomialFeatures(include_bias = False)
test_poly = poly.fit_transform(num_test_2)

# %%
ss = StandardScaler()
ss.fit(X_poly)
X_scaled = ss.transform(X_poly)

# %%
ss = StandardScaler()
ss.fit(test_poly)
test_scaled = ss.transform(test_poly)

# %%
lr.fit(X_scaled, y_train)
lr.score(X_scaled, y_train)
# Out:
# 0.8069073477493527

# %%
model =slr.fit(X_scaled, y_train)
y_hat = model.predict(test_scaled)

# %%
y_hat
# Out:
# array([175391.78442994, 274015.85100384, 160743.9254336 , 136433.28828036,
#        205635.93034983, 113157.15505099, 130865.75689708, 152881.71322823,
#        176864.05876616, 172070.57511927, 167661.95270392, 144743.9242907 ,
#        185581.7248876 , 321603.84144112, 159257.87015643,  89078.53456812,
#        153837.11736767, 134043.06983794, 212994.85433942, 183277.87957678,
