# %%
import numpy as np
import pandas as pd
import patsy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.feature_selection import SelectKBest

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
train = pd.read_csv('./train.csv')

# %%
test = pd.read_csv('./test.csv')

# %%
y = train['SalePrice']
X = train.drop(['SalePrice'], axis = "columns")

# %%
test_id = test['Id']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
def clean_me(df):
    #Replaces Null values outside of object columns 
    for i in range(len(df.columns)): 
        if [df.iloc[: ,i].dtypes!=object] == True:
            mean = df.iloc[: ,i].mean()
            df.iloc[: ,i].fillna(mean, inplace=True)
        else:
            pass
        #Replaces other null values with AANone
    str_cols = df.columns[df.dtypes==object]
    df[str_cols] = df[str_cols].fillna('AANone')
    df.fillna(0,inplace=True)
        #Change selected columns from Int to float
    for col in ['Low Qual Fin SF', 'Gr Liv Area', 'Lot Area', '1st Flr SF', '2nd Flr SF',
                'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val']:
                df[col] = df[col].astype('float64')
        #Makes remaining int colomns objects 
    int_cols = df.columns[df.dtypes=='int64']
    df[int_cols] = df[int_cols].astype('object')
    df = df.drop(['Id', 'PID'], axis=1)
    return df

# %%
X_train = clean_me(X_train)
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test = clean_me(X_test)
# Out:
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# C:\Users\jmvail\Anaconda3\envs\dsi\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test = clean_me(test)

# %% [markdown]
# **Cleaning Done**

# %% [markdown]
# Chose variables used in Linear Regression 1 along with selected dummy variables (dummies chosen by which I liked)

# %%
X_train.head()
# Out:
#      MS SubClass MS Zoning  Lot Frontage  Lot Area Street   Alley Lot Shape  \
# 1158          20        RL          91.0   11778.0   Pave  AANone       Reg
# 205           50        RM          52.0    6240.0   Pave  AANone       Reg
# 1560          20        RL          50.0   14859.0   Pave  AANone       IR1
# 1865          20        RL           0.0   11677.0   Pave  AANone       IR1
# 869           70        RL          50.0    4960.0   Pave  AANone       Reg
#
#      Land Contour Utilities Lot Config    ...    3Ssn Porch Screen Porch  \
# 1158          Lvl    AllPub     Inside    ...           0.0        255.0
# 205           Lvl    AllPub     Inside    ...           0.0          0.0
# 1560          HLS    AllPub    CulDSac    ...           0.0          0.0
# 1865          Lvl    AllPub     Inside    ...           0.0          0.0
# 869           Lvl    AllPub     Inside    ...           0.0          0.0
#
#      Pool Area Pool QC   Fence Misc Feature Misc Val Mo Sold Yr Sold Sale Type
# 1158       0.0  AANone  AANone       AANone      0.0       6    2008       WD
# 205        0.0  AANone  AANone       AANone      0.0       5    2010       WD
# 1560       0.0  AANone  AANone       AANone      0.0       8    2006       New
# 1865       0.0  AANone   MnPrv       AANone      0.0       2    2007       WD
# 869        0.0  AANone  AANone       AANone      0.0       5    2009       WD
#
# [5 rows x 78 columns]

# %%
X_train.columns
# Out:
# Index(['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Pool QC', 'Fence', 'Misc Feature',
#        'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %%
col = ['Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Garage Area', 'MS Zoning', 'Neighborhood',
       'Condition 1', 'House Style', 'Misc Feature', 'Fireplace Qu', 'Year Remod/Add', 'Paved Drive', ]

# %%
X_train = X_train[col]

# %%
X_test = X_test[col]

# %%
test = test[col]

# %%
def get_dummied(train, test):
    list = []
    
    for i in train.columns:
        if train[i].dtype == object:
            list.append(i)
            
    full_data = pd.concat([train, test], axis=0)
    full_data = pd.get_dummies(full_data, columns=list, drop_first=True)
    
    X_dummied = full_data[:len(train)]
    test_dummied = full_data.iloc[-len(test):]

    
    return X_dummied, test_dummied

# %%
X_train_dum, X_test_dum = get_dummied(X_train, X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_dum, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lr.score(X_test_dum, y_test))
# Out:
# 0.7723772323367117

# %% [markdown]
# Rsquared improved from first Linear Regression

# %%
X_train_dum, test_dum = get_dummied(X_train, test)

# %%
model = lr.fit(X_train_dum, y_train)
y_hat = model.predict(test_dum)

# %%
y_hat
# Out:
# array([163051.13591155, 231476.91955968, 181104.46258144, 122280.93744199,
#        184010.32898421,  88701.52428849, 126116.69358585, 158883.7664796 ,
#        198666.63576665, 158760.61151519, 149832.76760797, 132065.84963533,
#        176650.94815716, 283431.63602316, 195509.69969263, 118538.45087107,
#        150557.17101109, 131254.35306478, 231747.33154949, 156320.39796696,
#        155362.67951595, 105520.02697286, 223575.99528411, 133683.55962557,
#        188735.74062804, 112528.19037762, 178202.53438164, 101871.04442731,
#        131312.28772131,  34583.30017136, 109264.05803239, 111506.40726534,
#        268222.10166951, 168977.74806906, 230586.63172886, 160056.12551798,
#        131096.27004011,  78991.22609383,  91424.12783937, 211983.60373045,
#        207958.03497662, 206119.41453179, 177380.06318486, 175340.59416871,
#        220019.11761006, 157999.54992864, 218578.83109686, 109260.37194488,
#        128237.53111502, 109922.99112605,  93469.39801462, 181476.9051381 ,
#        259486.42166244, 135961.53553771, 234798.3388176 , 142756.95033798,
#        241836.57511414, 175769.4525667 , 290604.4732588 , 177449.71007224,
#        183166.37560517, 293466.20060569, 158382.15997112, 277143.08839374,
#        151143.24478858, 196199.37930414, 220334.2110593 , 128419.9624321 ,
#        187848.88969372, 229465.2857312 , 116450.47629272, 133989.07525831,
#        211010.70398061, 194173.40617083, 368978.28998507,  91405.31501871,
#        144823.04106743, 100625.1394667 , 202926.37375238, 271100.6421983 ,
#        110003.60373034, 265553.06675662, 173153.30866133, 168484.61308733,
#        250086.6390837 , 172917.57191224, 302170.01482839, 204502.05082831,
#        204455.24131987, 158952.57900354, 305646.34490307, 252255.98115924,
#        194004.05009323, 139166.93191106, 102759.77483566, 163527.59925913,
#        113908.74292017, 238920.27846933, 118482.35363086, 141834.8448933 ,
#        176716.15650314, 157494.67787936, 102633.58081814, 139740.47542327,
#        321984.41905464, 133567.48013505, 206692.00607682, 288617.02061064,
#        241877.46747071, 266275.54184891,  95148.54695551, 113457.86592631,
#        145804.46921494, 180958.67298606, 120055.8714617 , 374605.43988033,
#        153748.72713001, 184318.4296736 , 180968.76804602, 345512.08637274,
#        146374.37723641, 203217.03610592, 161433.01562698, 172830.21722988,
#        146491.02797296, 267614.09173709, 266297.7096553 , 142614.69833661,
#        128375.85987872, 329035.25812404, 144252.49565176, 100611.06658125,
#        131605.97371655, 207434.87188127, 218631.99852215, 191685.44949193,
#        126463.99222891, 160953.72551954, 157644.7636943 , 291915.37360582,
#        274666.5337642 , 109566.55132694, 170108.14527058, 150440.35497188,
#        154760.3304544 ,  98515.66754271, 142700.16335499, 163987.24399769,
#        133422.81172389, 254057.4404218 , 108633.72213278, 189413.1716526 ,
#         87224.72297839, 337885.99984253, 112145.56088335, 131186.3847551 ,
#        180558.740121  , 173319.70487185, 198334.16565242, 226619.78260474,
#        286621.66374673, 239271.77226154, 189961.98099729, 226473.34363843,
#        394272.10055486, 202021.85721027, 212371.23798846, 225332.79734112,
#        131299.20660872, 103107.35515573, 124458.54437762])

# %%
pd.options.display.max_rows = 999

# %%
pd.options.display.max_rows
# Out:
# 999

# %%
coefs = pd.DataFrame([model.coef_], columns=X_train_dum.columns)
coefs.T
# Out:
#                                  0
# Total Bsmt SF         4.263518e+01
# 1st Flr SF            9.967198e+00
# Gr Liv Area           5.761673e+01
# Garage Area           4.370524e+01
# MS Zoning_C (all)    -1.011754e+04
# MS Zoning_FV          1.106654e+04
# MS Zoning_I (all)    -9.973264e-07
# MS Zoning_RH         -1.707975e+03
# MS Zoning_RL          4.363177e+03
# MS Zoning_RM         -4.596828e+02
# Neighborhood_Blueste  1.008657e+04
# Neighborhood_BrDale   1.630133e+04
# Neighborhood_BrkSide  9.299939e+03
# Neighborhood_ClearCr  1.752318e+04
# Neighborhood_CollgCr  1.734072e+04
# Neighborhood_Crawfor  2.487854e+04
# Neighborhood_Edwards  2.039351e+03
# Neighborhood_Gilbert  1.023951e+04
# Neighborhood_Greens   3.927491e+04
# Neighborhood_GrnHill  1.448882e+05
# Neighborhood_IDOTRR   5.857505e+03
# Neighborhood_MeadowV  2.540492e+03
# Neighborhood_Mitchel  6.901737e+03
# Neighborhood_NAmes    3.994121e+03
# Neighborhood_NPkVill  1.640940e+04
# Neighborhood_NWAmes   3.489532e+03
# Neighborhood_NoRidge  6.772777e+04
# Neighborhood_NridgHt  6.024008e+04
# Neighborhood_OldTown -4.185631e+03
# Neighborhood_SWISU   -1.772853e+03
# Neighborhood_Sawyer   4.503789e+03
# Neighborhood_SawyerW  1.374254e+04
# Neighborhood_Somerst  2.147988e+04
# Neighborhood_StoneBr  7.442651e+04
# Neighborhood_Timber   2.398249e+04
# Neighborhood_Veenker  4.415685e+04
# Condition 1_Feedr     6.312877e+03
# Condition 1_Norm      1.435545e+04
# Condition 1_PosA      3.562897e+04
# Condition 1_PosN      3.459114e+04
# Condition 1_RRAe      1.156732e+04
# Condition 1_RRAn      1.049843e+04
# Condition 1_RRNe      1.185458e+04
# Condition 1_RRNn      5.378676e+03
# House Style_1.5Unf    1.683903e+04
# House Style_1Story    1.132826e+04
# House Style_2.5Fin   -3.735386e+04
# House Style_2.5Unf   -8.533089e+02
# House Style_2Story    1.360016e+04
# House Style_SFoyer    2.919781e+04
# House Style_SLvl      2.329222e+04
# Misc Feature_Elev    -5.004361e+05
# Misc Feature_Gar2    -3.939941e+03
# Misc Feature_Othr     2.338991e+04
# Misc Feature_Shed     6.062147e+03
# Fireplace Qu_Ex       3.295245e+04
# Fireplace Qu_Fa       8.931666e+03
# Fireplace Qu_Gd       1.853359e+04
# Fireplace Qu_Po      -7.078875e+02
# Fireplace Qu_TA       9.986951e+03
# Year Remod/Add_1951  -6.426130e+03
# Year Remod/Add_1952  -2.396538e+04
# Year Remod/Add_1953  -4.875158e+03
# Year Remod/Add_1954   4.814361e+03
# Year Remod/Add_1955   4.630762e+03
# Year Remod/Add_1956   9.155856e+03
# Year Remod/Add_1957  -1.548915e+04
# Year Remod/Add_1958  -2.753612e+03
# Year Remod/Add_1959  -2.291346e+02
# Year Remod/Add_1960  -9.632309e+03
# Year Remod/Add_1961  -5.097000e+03
# Year Remod/Add_1962  -3.207991e+03
# Year Remod/Add_1963  -1.561576e+03
# Year Remod/Add_1964  -5.718630e+02
# Year Remod/Add_1965   1.022729e+03
# Year Remod/Add_1966   1.329913e+04
# Year Remod/Add_1967  -1.532088e+04
# Year Remod/Add_1968   1.410859e+03
# Year Remod/Add_1969  -2.309035e+04
# Year Remod/Add_1970  -7.616214e+03
# Year Remod/Add_1971  -6.126705e+03
# Year Remod/Add_1972  -2.360344e+03
# Year Remod/Add_1973   9.016833e+03
# Year Remod/Add_1974   2.957162e+03
# Year Remod/Add_1975  -7.896831e+03
# Year Remod/Add_1976  -6.164386e+03
# Year Remod/Add_1977  -2.111151e+03
# Year Remod/Add_1978  -4.565320e+03
# Year Remod/Add_1979  -6.244481e+03
# Year Remod/Add_1980  -1.248341e+03
# Year Remod/Add_1981  -1.899903e+04
# Year Remod/Add_1982   1.948485e+03
# Year Remod/Add_1983   8.585472e+03
# Year Remod/Add_1984   4.768323e+03
# Year Remod/Add_1985   1.576206e+03
# Year Remod/Add_1986   6.090916e+03
# Year Remod/Add_1987   1.129946e+04
# Year Remod/Add_1988   3.276731e+04
# Year Remod/Add_1989   3.837239e+03
# Year Remod/Add_1990   3.890328e+03
# Year Remod/Add_1991  -6.134025e+03
# Year Remod/Add_1992   1.548339e+04
# Year Remod/Add_1993   1.651163e+03
# Year Remod/Add_1994   1.300260e+04
# Year Remod/Add_1995   8.265522e+03
# Year Remod/Add_1996   1.642370e+04
# Year Remod/Add_1997   1.549731e+04
# Year Remod/Add_1998   1.071685e+04
# Year Remod/Add_1999   2.000532e+04
# Year Remod/Add_2000   2.068285e+04
# Year Remod/Add_2001   2.530501e+04
# Year Remod/Add_2002   2.417454e+04
# Year Remod/Add_2003   2.072296e+04
# Year Remod/Add_2004   1.459644e+04
# Year Remod/Add_2005   2.336437e+04
# Year Remod/Add_2006   2.381050e+04
# Year Remod/Add_2007   2.863785e+04
# Year Remod/Add_2008   5.241928e+04
# Year Remod/Add_2009   6.477673e+04
# Year Remod/Add_2010   1.016961e+05
# Paved Drive_P         5.896465e+03
# Paved Drive_Y         7.125949e+03

# %%
#dum_trial_2 = pd.DataFrame(y_hat, index = test_id)
#dum_trial_2.columns = ['SalePrice']
#dum_trial_2.head
# Out:
# <bound method NDFrame.head of           SalePrice
# Id
# 2658  158005.386347
# 2718  209137.583857
# 2414  182341.427306
# 1989  110594.647977
# 625   181092.603890
# 333    88839.162089
# 1327  105676.290234
# 858   171002.480486
# 95    213063.711096
# 1568  171645.350493
# 2482  166557.016331
# 1364  109043.980480
# 2584  169413.392304
# 818   261867.525714
# 2673  172221.905748
# 2089  108701.229249
# 1297  163234.481352
# 790   118875.985158
# 2616  229905.720872
# 720   150771.618840
# 222   136538.970444
# 557   112114.499880
# 1148  213816.082700
# 2766  177601.145084
# 534   171388.749597
# 1452  144989.471805
# 630   145859.053598
# 2648  112823.232777
# 125   126362.227630
# 1904   45419.554019
# ...             ...
# 933   131034.393874
# 2784  184522.641261
# 972   144981.358672
# 599   158901.780848
# 2614  108327.928952
# 2582  160160.499651
# 1409  167337.178746
# 175   131108.227837
# 352   272555.225077
# 976    89343.439656
# 2134  190266.565402
# 984   100697.748427
# 2396  336184.546389
# 1673  120281.541816
# 404   136072.317888
# 607   173048.046347
# 814   183640.639598
# 868   196350.561865
# 2271  227712.979613
# 1633  313412.470018
# 337   230158.031418
# 2765  206593.343372
# 1746  220249.633476
# 368   355613.221869
# 2806  195560.741565
# 1662  204808.669890
# 1234  199872.484410
# 1373  124568.456074
# 1672  120731.109573
# 1939  131681.667131
#
# [879 rows x 1 columns]>

# %%
#dum_trial_2.describe()
# Out:
#            SalePrice
# count     879.000000
# mean   179800.010593
# std     68526.337024
# min     35722.256002
# 25%    127610.073676
# 50%    168743.836922
# 75%    217780.507977
# max    474849.977510

# %%
#dum_trial_2.to_csv("./dum_trial_2.csv")
